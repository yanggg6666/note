# %% [markdown]
# <a href="https://colab.research.google.com/github/yanggg6666/note/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

x=[1,4,9,16,25]

y=[i*i for i in x]

plt.plot(y)

# %%
import pandas as pd
series = pd.Series(y)
series.plot()
# Out:
# <Axes: >
